# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
import mdtraj as md
import pandas as pd
from numpy import random

# %% [markdown]
# # Checking convergence rate with change in sigma values

# %% [markdown]
# ## Sigma = 0.3, Height = 1.2

# %%
for i in range(0,100):
    fes_i= np.loadtxt('./sigma-0.3_height-1.2/fes_'+str(i)+'.dat', skiprows = 5)
    phi_fes_i = fes_i[:,0]
    energy_fes_i = fes_i[:,1]
    plt.plot(phi_fes_i, energy_fes_i, label = str((i+1)/10)+"ns")
    
plt.xlabel('$\phi$ (rad)')
plt.ylabel('Energy (kJ/mol)')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title('dialaA-sigma-0.3-height-1.2-bf-10')
plt.savefig('../../../figures/dialaA-sigma-0.3-height-1.2-bf-10.png')
plt.show()

# %% [markdown]
# ## Sigma = 0.4, Height = 1.2

# %%
for i in range(0,100):
    fes_i= np.loadtxt('./sigma-0.4_height-1.2/fes_'+str(i)+'.dat', skiprows = 5)
    phi_fes_i = fes_i[:,0]
    energy_fes_i = fes_i[:,1]
    plt.plot(phi_fes_i, energy_fes_i, label = str((i+1)/10)+"ns")
    
plt.xlabel('$\phi$ (rad)')
plt.ylabel('Energy (kJ/mol)')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title('dialaA-sigma-0.4-height-1.2-bf-10')
plt.savefig('../../../figures/dialaA-sigma-0.4-height-1.2-bf-10.png')
plt.show()

# %% [markdown]
# ## Sigma 0.5, Height = 1.2

# %%
for i in range(0,100):
    fes_i= np.loadtxt('./sigma-0.5_height-1.2/fes_'+str(i)+'.dat', skiprows = 5)
    phi_fes_i = fes_i[:,0]
    energy_fes_i = fes_i[:,1]
    plt.plot(phi_fes_i, energy_fes_i, label = str((i+1)/10)+"ns")
    
plt.xlabel('$\phi$ (rad)')
plt.ylabel('Energy (kJ/mol)')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title('dialaA-sigma-0.5-height-1.2-bf-10')
plt.savefig('../../../figures/dialaA-sigma-0.5-height-1.2-bf-10.png')
plt.show()

# %% [markdown]
# ## Sigma = 0.6, Height = 1.2

# %%
for i in range(0,100):
    fes_i= np.loadtxt('./sigma-0.6_height-1.2/fes_'+str(i)+'.dat', skiprows = 5)
    phi_fes_i = fes_i[:,0]
    energy_fes_i = fes_i[:,1]
    plt.plot(phi_fes_i, energy_fes_i, label = str((i+1)/10)+"ns")
    
plt.xlabel('$\phi$ (rad)')
plt.ylabel('Energy (kJ/mol)')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title('dialaA-sigma-0.6-height-1.2-bf-10')
plt.savefig('../../../figures/dialaA-sigma-0.6-height-1.2-bf-10.png')
plt.show()

# %% [markdown]
# ## Sigma = 0.7, Height = 1.2

# %%
for i in range(0,100):
    fes_i= np.loadtxt('./sigma-0.7_height-1.2/fes_'+str(i)+'.dat', skiprows = 5)
    phi_fes_i = fes_i[:,0]
    energy_fes_i = fes_i[:,1]
    plt.plot(phi_fes_i, energy_fes_i, label = str((i+1)/10)+"ns")
    
plt.xlabel('$\phi$ (rad)')
plt.ylabel('Energy (kJ/mol)')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title('dialaA-sigma-0.7-height-1.2-bf-10')
plt.savefig('../../../figures/dialaA-sigma-0.7-height-1.2-bf-10.png')
plt.show()

# %% [markdown]
# ## Checking convergence rate with change in Height value

# %% [markdown]
# ## Sigma = 0.5, Height = 0.4

# %%
for i in range(0,100):
    fes_i= np.loadtxt('./sigma-0.5_height-0.4/fes_'+str(i)+'.dat', skiprows = 5)
    phi_fes_i = fes_i[:,0]
    energy_fes_i = fes_i[:,1]
    plt.plot(phi_fes_i, energy_fes_i, label = str((i+1)/10)+"ns")
    
plt.xlabel('$\phi$ (rad)')
plt.ylabel('Energy (kJ/mol)')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title('dialaA-sigma-0.5-height-0.4-bf-10')
plt.savefig('../../../figures/dialaA-sigma-0.5-height-0.4-bf-10.png')
plt.show()

# %% [markdown]
# ## Sigma = 0.5, Height = 0.8

# %%
for i in range(0,100):
    fes_i= np.loadtxt('./sigma-0.5_height-0.8/fes_'+str(i)+'.dat', skiprows = 5)
    phi_fes_i = fes_i[:,0]
    energy_fes_i = fes_i[:,1]
    plt.plot(phi_fes_i, energy_fes_i, label = str((i+1)/10)+"ns")
    
plt.xlabel('$\phi$ (rad)')
plt.ylabel('Energy (kJ/mol)')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title('dialaA-sigma-0.5-height-0.8-bf-10')
plt.savefig('../../../figures/dialaA-sigma-0.5-height-0.8-bf-10.png')
plt.show()

# %% [markdown]
# ## Sigma = 0.5, Height = 1.2

# %%
for i in range(0,100):
    fes_i= np.loadtxt('./sigma-0.5_height-1.2/fes_'+str(i)+'.dat', skiprows = 5)
    phi_fes_i = fes_i[:,0]
    energy_fes_i = fes_i[:,1]
    plt.plot(phi_fes_i, energy_fes_i, label = str((i+1)/10)+"ns")
    
plt.xlabel('$\phi$ (rad)')
plt.ylabel('Energy (kJ/mol)')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title('dialaA-sigma-0.5-height-1.2-bf-10')
plt.savefig('../../../figures/dialaA-sigma-0.5-height-1.2-bf-10.png')
plt.show()

# %% [markdown]
# ## Sigma = 0.5, Height = 1.6

# %%
for i in range(0,100):
    fes_i= np.loadtxt('./sigma-0.5_height-1.6/fes_'+str(i)+'.dat', skiprows = 5)
    phi_fes_i = fes_i[:,0]
    energy_fes_i = fes_i[:,1]
    plt.plot(phi_fes_i, energy_fes_i, label = str((i+1)/10)+"ns")
    
plt.xlabel('$\phi$ (rad)')
plt.ylabel('Energy (kJ/mol)')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title('dialaA-sigma-0.5-height-1.6-bf-10')
plt.savefig('../../../figures/dialaA-sigma-0.5-height-1.6-bf-10.png')
plt.show()

# %% [markdown]
# ## Sigma = 0.5, Height = 2.0

# %%
for i in range(0,100):
    fes_i= np.loadtxt('./sigma-0.5_height-2.0/fes_'+str(i)+'.dat', skiprows = 5)
    phi_fes_i = fes_i[:,0]
    energy_fes_i = fes_i[:,1]
    plt.plot(phi_fes_i, energy_fes_i, label = str((i+1)/10)+"ns")
    
plt.xlabel('$\phi$ (rad)')
plt.ylabel('Energy (kJ/mol)')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title('dialaA-sigma-0.5-height-2.0-bf-10')
plt.savefig('../../../figures/dialaA-sigma-0.5-height-2.0-bf-10.png')
plt.show()

# %% [markdown]
# #

# %%
# defining paths for files
colvar_1_path = './sigma-0.5_height-1.2/COLVAR_METAD'
hills_1_path = './sigma-0.5_height-1.2/HILLS'
grid_1_path = './sigma-0.5_height-1.2/metad.grid.dat'
# load data
colvar_1 = np.loadtxt(colvar_1_path)
hills_1 = np.loadtxt(hills_1_path)
grid_1 = np.loadtxt(grid_1_path)

# %%
# figure 5 - bias landscape & free energy landscape
fig,axs=plt.subplots(1,2,layout=None, figsize=(12,5))
# data processing, load time in ns
phi_1 = grid_1[:,0]
bias_1 = grid_1[:,1]
derivatives_phi_1 = grid_1[:,2]
biasfactor_1 = 10
free_energy_1 = bias_1 * (biasfactor_1/(1-biasfactor_1))
free_energy_derivatives_phi_1 = derivatives_phi_1 * (biasfactor_1/(1-biasfactor_1))

# set colorblind-friendly palatte
colors = ['#0077BB', '#33BBEE', '#009988', '#EE7733', '#CC3311', '#EE3377', '#BBBBBB']

# plot minus bias potential over phi, colorblind friendly, line width 2
axs[0].plot(phi_1, -bias_1, c=colors[0], lw=2, label='minus bias potential ''-V')
# set axis range
axs[0].set_xlim(-np.pi, np.pi)
# labels, font size 12
axs[0].set_xlabel(r'$\phi$ (rad)', fontsize=12)
axs[0].set_ylabel('Minus Bias Potential (kJ/mol)', fontsize=12)
# title
axs[0].set_title("negative of bias potential landscape", fontsize=12)
# plot derivatives of minus bias potential over phi, colorblind friendly, line width 1, dashed, right y axis
ax0_2=axs[0].twinx()
ax0_2.plot(phi_1, -derivatives_phi_1, c=colors[1], lw=1, ls='--', label='minus derivative 'r'$-\frac{\partial V}{\partial \phi}$')
# labels, font size 12
ax0_2.set_ylabel('Derivative (kJ/mol'r'$\bullet$''rad))', fontsize=12)
# combine legend for twinx
axs[0].legend(loc='upper left', bbox_to_anchor=(0,1), bbox_transform=axs[0].transAxes, fontsize=12, frameon=False)
ax0_2.legend(loc='upper left', bbox_to_anchor=(-0.003,0.95), bbox_transform=axs[0].transAxes, fontsize=12, frameon=False)

# plot free energy over phi, colorblind friendly, line width 2
axs[1].plot(phi_1, free_energy_1, c=colors[0], lw=2, label='free energy 'r'$F$')
# set axis range
axs[1].set_xlim(-np.pi, np.pi)
# labels, font size 12
axs[1].set_xlabel(r'$\phi$ (rad)', fontsize=12)
axs[1].set_ylabel('Free Energy (kJ/mol)', fontsize=12)
# title
axs[1].set_title("Free energy landscape", fontsize=12)
# plot derivatives of free energy over phi, colorblind friendly, line width 1, dashed, right y axis
ax1_2=axs[1].twinx()
ax1_2.plot(phi_1, free_energy_derivatives_phi_1, c=colors[1], lw=1, ls='--', label='derivative 'r'$\frac{\partial F}{\partial \phi}$')
# labels, font size 12
ax1_2.set_ylabel('Derivative (kJ/mol'r'$\bullet$''rad))', fontsize=12)
# combine legend for twinx
axs[1].legend(loc='upper left', bbox_to_anchor=(0,1.01), bbox_transform=axs[1].transAxes, fontsize=12, frameon=False)
ax1_2.legend(loc='upper left', bbox_to_anchor=(-0.003,0.94), bbox_transform=axs[1].transAxes, fontsize=12, frameon=False)

# title
plt.text(x=0.5, y=0.95, s="Bias potential & free energy landscape", fontsize=18, ha="center", transform=fig.transFigure)
plt.text(x=0.5, y=0.9, s= "dialaA, biasfactor10, pace500, height12, sigma0.5", fontsize=11, ha="center", transform=fig.transFigure)
plt.subplots_adjust(top=0.8, wspace=0.4)

# save figure as pdf in ../Figures
plt.savefig('../../../figures/fes-comparison-sigma-0.5-height-1p2-dialaA.png', format='pdf', dpi=300, bbox_inches='tight')
