# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md
import numpy as np
import pandas as pd

# %%
fes = pd.read_csv('./fes.dat', sep='\s+', skiprows=9, header=None)
fes.columns = ['phi', 'psi', 'free ene', 'der_phi', 'der_psi']
fes
# Out:
#           phi       psi    free ene    der_phi    der_psi
# 0   -3.141593 -3.141593  -99.386900 -53.484196  16.861994
# 1   -2.951193 -3.141593 -107.835552 -34.622439  19.411134
# 2   -2.760794 -3.141593 -112.444100 -14.109480  20.995564
# 3   -2.570394 -3.141593 -113.440553   2.573844  21.714164
# 4   -2.379994 -3.141593 -111.918808  12.075614  21.995741
# ..        ...       ...         ...        ...        ...
# 589  2.189595  2.792527  -50.354411 -11.259025  -7.570553
# 590  2.379994  2.792527  -55.047408 -37.635492  -5.960155
# 591  2.570394  2.792527  -64.346894 -58.734317  -4.421028
# 592  2.760794  2.792527  -76.781629 -69.975511  -2.745508
# 593  2.951193  2.792527  -90.215112 -69.087280  -0.825462
#
# [594 rows x 5 columns]

# %%
phi=fes['phi'].to_numpy()
psi=fes['psi'].to_numpy()
ene=fes['free ene'].to_numpy()

# %%
phi_new=phi[:33]
psi_new=psi[::33]
ene_new=ene.reshape(18,33)

# %%
plt.figure()
plt.imshow(ene_new, origin='lower', interpolation='nearest', extent=[phi_new[0], phi_new[-1], psi_new[0], psi_new[-1]], cmap='viridis')
plt.xlabel('$\phi$')
plt.ylabel('$\psi$')
plt.title('Free Energy Surface-dialaA-2D')
plt.colorbar(label='Free Energy (kJ/mol)')
plt.savefig('FES_part_6.png')
plt.show()

# %%
plt.contourf(phi_new, psi_new, ene_new, 20)
plt.xlabel('$\phi$')
plt.ylabel('$\psi$')
plt.title('Free Energy Surface-dialaA-2D-metaD')
plt.colorbar(label='Free Energy (kJ/mol)')
plt.savefig('../../../figures/diala-fes-metad2D.png')
plt.show()
